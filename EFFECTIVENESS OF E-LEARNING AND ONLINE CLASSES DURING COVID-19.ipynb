# %% [markdown]
# ## **EFFECTIVENESS OF E-LEARNING AND ONLINE CLASSES DURING COVID-19**

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')  
os.chdir("/content/drive/My Drive/Colab Notebooks/")
sys.path.append("/content/drive/My Drive/Colab Notebooks/")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
data=pd.read_csv("covid.csv")

# %%
import scipy
from scipy import stats

import seaborn as sns
from sklearn.tree import plot_tree
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## **View Data**

# %%
data
# Out:
#               Timestamp  ...                                        suggestions
# 0      09-12-2020 19.39  ...                                                nil
# 1      09-12-2020 19.39  ...                                                nil
# 2      09-12-2020 19.41  ...                                                nil
# 3      09-12-2020 19.41  ...                                                nil
# 4      09-12-2020 19.43  ...  Make more comfortable for students as if they ...
# ..                  ...  ...                                                ...
# 255  9/13/2020 13:03:43  ...                                                nil
# 256  9/13/2020 13:04:12  ...  Online class is so difficult to catch my chapters
# 257  9/13/2020 13:05:03  ...                                                nil
# 258  9/13/2020 13:07:06  ...           The classes are  Must be in the morning.
# 259  9/13/2020 13:10:49  ...                                                nil
#
# ...

# %% [markdown]
# **Information about a DataFrame including the index dtype and columns, non-null values and memory usage**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 20 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Timestamp                                                       260 non-null    object
#  1   Name                                                            260 non-null    object
#  2   Gender                                                          260 non-null    object
#  3   Name of the Institution                                         260 non-null    object
#  4   Educational Qualification                                       260 non-null    object
#  5   Familys Annual Income                                           260 non-null    object
#  6   which is better for quality education                           260 non-null    object
# ...

# %% [markdown]
# **Summary of statistics pertaining to the DataFrame columns**

# %%
data.describe()
# Out:
#        Network/Internet Connection issues  ...  Lack of classroom atmosphere & background noises
# count                          260.000000  ...                                         260.000000
# mean                             2.088462  ...                                           2.288462
# std                              1.482153  ...                                           1.585851
# min                              1.000000  ...                                           1.000000
# 25%                              1.000000  ...                                           1.000000
# 50%                              2.000000  ...                                           2.000000
# 75%                              3.000000  ...                                           3.000000
# max                              6.000000  ...                                           6.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# **Dimensionality of the DataFrame**

# %%
data.shape
# Out:
# (260, 20)

# %% [markdown]
# **Count non-NA cells for each column or row**

# %%
data.count()
# Out:
# Timestamp                                                         260
# Name                                                              260
# Gender                                                            260
# Name of the Institution                                           260
# Educational Qualification                                         260
# Familys Annual Income                                             260
# which is better for quality education                             260
# level of satisfaction on E-learning and online classes            260
# Mode/Medium of device used for attending online classes           260
# offer the same student support services as that of traditional    260
# guidelines are provided by your lecturer before                   260
# recharging an additional financial burden                         260
# financial aid from Govt./any other authority                      260
# ...

# %% [markdown]
# **Count unique combinations of Timestamp**

# %%
data['Timestamp'].value_counts()
# Out:
# 09-12-2020 20.29      6
# 09-12-2020 20.08      5
# 09-12-2020 20.02      4
# 09-12-2020 19.49      4
# 09-12-2020 20.39      4
#                      ..
# 09-12-2020 20.13      1
# 09-12-2020 23.13      1
# 09-12-2020 19.59      1
# 9/13/2020 11:47:32    1
# 09-12-2020 20.51      1
# Name: Timestamp, Length: 178, dtype: int64

# %% [markdown]
# **Count unique combinations of Gender**

# %%
data['Gender'].value_counts()
# Out:
# Female    152
# Male      108
# Name: Gender, dtype: int64

# %%
sns.countplot(data=data,x='Gender')

plt.show()

# %% [markdown]
# 58.85% of the respondents are female and 41.15% are male.

# %% [markdown]
# **Counts of observations of Educational Qualification**

# %%
data['Educational Qualification'].value_counts()
# Out:
# Graduation         164
# School              64
# Post-Graduation     32
# Name: Educational Qualification, dtype: int64

# %%
data['Educational Qualification'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# Majority of the respondents are attending the online classes in order
# to complete their regular graduation courses (63.1%).

# %% [markdown]
# **counts of observations of Familys Annual Income**

# %%
data['Familys Annual Income'].value_counts()
# Out:
# 25,000 - 50,000        75
# 50,000 - 1,00,000      67
# Below 25,000           55
# Above 2,00,000         41
# 1,00,000 - 2,00,000    22
# Name: Familys Annual Income, dtype: int64

# %%
data['Familys Annual Income'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend()
plt.title('Familys Annual Income')
plt.show()

# %% [markdown]
# Majority of the respondents belong to a low-income group category.
# Only a small number of respondents are having an annual family
# income above Rs.1,00,000.

# %% [markdown]
# **counts of observations of which is better for quality education**

# %%
data['which is better for quality education'].value_counts()
# Out:
# Traditional face-to face classes    240
# Online classes                       20
# Name: which is better for quality education, dtype: int64

# %%
data['which is better for quality education'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# Out of the 260 respondents, 240 (92.3%) are of the opinion that traditional
# face-to-face classes are better for quality education when compared to
# online classes. Only 20 (7.7%) respondents prefer online education in this
# regard.

# %% [markdown]
# **counts of observations of level of satisfaction on E-learning and online classes**

# %%
data['level of satisfaction on E-learning and online classes'].value_counts()
# Out:
# Neutral                100
# Satisfied               87
# Dissatisfied            48
# Highly Dissatisfied     18
# Highly Satisfied         7
# Name: level of satisfaction on E-learning and online classes, dtype: int64

# %%
data['level of satisfaction on E-learning and online classes'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend()
plt.show()

# %% [markdown]
# While identifying the satisfaction level of the respondents with regard to e-
# learning and online classes, it is found that majority (100 respondents) are neutral in their opinion. 33.5% of the respondents are satisfied and 18.5%
# are dissatisfied towards online education. Only a small number of
# respondents are of extreme satisfaction and dissatisfaction with regard to
# e-learning.

# %% [markdown]
# ## **counts of observations of Mode/Medium of device used for attending online classes**

# %%
data['Mode/Medium of device used for attending online classes '].value_counts()
# Out:
# Smart Phones                      199
# Laptops                            47
# TV                                  5
# Tab                                 5
# Desktop                             3
# Face to face traditional class      1
# Name: Mode/Medium of device used for attending online classes , dtype: int64

# %%
data['Mode/Medium of device used for attending online classes '].value_counts().plot.pie(autopct='%1.2f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# Majority of the respondents are using smart phones for attending the online
# classes (76.5%). 18.1% of the respondents use laptops and the rest of 5.4%
# use other mediums like TVs, desktops, tabs etc.

# %% [markdown]
# # **Analysis of Support Services provided in online classes**

# %%
data['offer the same student support services as that of traditional'].value_counts()
# Out:
# No     191
# Yes     69
# Name: offer the same student support services as that of traditional, dtype: int64

# %%
data['offer the same student support services as that of traditional'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# The study found out that online classes do not offer the same student
# services as that of traditional face-to-face classes.

# %% [markdown]
# ## **Analysis of guidelines provided by your lecturers before Online Classes**

# %%
data['guidelines are provided by your lecturer before'].value_counts()
# Out:
# Yes    215
# No      45
# Name: guidelines are provided by your lecturer before, dtype: int64

# %%
data['guidelines are provided by your lecturer before'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend()
plt.show()

# %% [markdown]
# Majority of the respondents are of the opinion that they are provided by
# necessary guidelines by the lecturers before the online sessions.

# %% [markdown]
# ## **Analysis of data recharging an additional financial burden for you, for the access to online classes**

# %%
data['recharging an additional financial burden'].value_counts()
# Out:
# Yes    158
# No     102
# Name: recharging an additional financial burden, dtype: int64

# %%
data['recharging an additional financial burden'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# It is identified that data recharging tends to be an additional financial
# burden for most of the respondents for the access to online classes.

# %% [markdown]
# ## **Analysis of getting any sort of financial aid from Govt./ any other authority for attending online classes**

# %%
data['financial aid from Govt./any other authority'].value_counts()
# Out:
# No     242
# Yes     18
# Name: financial aid from Govt./any other authority, dtype: int64

# %%
data['financial aid from Govt./any other authority'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(20,10),fontsize=(18))
plt.legend().figsize=(30,20)
plt.show()

# %% [markdown]
# The study found out that 93.1% of the respondents are not getting any sort
# of financial aid from Govt./any other authority for attending the online
# classes.

# %% [markdown]
# ## **Rank the following statements (challenges faced by you) in the order in which they affect you the most, to the success of online classes:**
#
# ---
#
# > Rank from 1 to 6
#
# # The study comes across many challenges faced by the students to the success of online classes

# %% [markdown]
# # **Count of Network/Internet connection issues**

# %%
data['Network/Internet Connection issues'].value_counts()
# Out:
# 1    129
# 2     60
# 3     34
# 6     20
# 4     13
# 5      4
# Name: Network/Internet Connection issues, dtype: int64

# %%
sns.countplot(data=data,x='Network/Internet Connection issues')
plt.show()

# %% [markdown]
# The network/internet connection issues are identified as the major challenge faced by the respondents in attending online sessions

# %% [markdown]
# ## **Count of Lack of face-to-face interaction with teachers and friends**

# %%
data['Lack of face-to-face interaction with teachers and friends'].value_counts()
# Out:
# 1    116
# 2     68
# 3     38
# 6     20
# 5     12
# 4      6
# Name: Lack of face-to-face interaction with teachers and friends, dtype: int64

# %%
sns.countplot(data=data,x='Lack of face-to-face interaction with teachers and friends')
plt.show()

# %% [markdown]
# The lack of face-to-face interaction with teachers and friends stands
# as the next major challenge

# %% [markdown]
# ## **Count of Lack of familiarity to the use of technology**

# %%
data['Lack of familiarity to the use of technology'].value_counts()
# Out:
# 2    97
# 1    87
# 6    30
# 3    30
# 5     8
# 4     8
# Name: Lack of familiarity to the use of technology, dtype: int64

# %%
sns.countplot(data=data,x='Lack of familiarity to the use of technology')
plt.show()

# %% [markdown]
# The responses show that the lack of familiarity to the use of technology is not a challenge faced by the students. Most of the students are capable of using latest technologies with ease

# %% [markdown]
# # **Count of Lack of availability of good infrastructural facilities (smart phones,laptops etc.)**

# %%
data['Lack of good infrastructural facilities'].value_counts()
# Out:
# 1    111
# 2     68
# 3     33
# 6     19
# 5     15
# 4     14
# Name: Lack of good infrastructural facilities, dtype: int64

# %%
sns.countplot(data=data,x='Lack of good infrastructural facilities')
plt.show()

# %% [markdown]
# # ***Count of Mental/Psychological difficulty with regard to sudden shifting from traditional classrooms to online classes ***

# %%
data['Mental/Psychological difficulty with sudden shifting'].value_counts()
# Out:
# 1    94
# 2    82
# 3    36
# 4    22
# 6    19
# 5     7
# Name: Mental/Psychological difficulty with sudden shifting, dtype: int64

# %%
sns.countplot(data=data,x='Mental/Psychological difficulty with sudden shifting')
plt.show()

# %% [markdown]
# # **Count of Lack of classroom atmosphere & background noises and disturbances from the surroundings**

# %%
data['Lack of classroom atmosphere & background noises '].value_counts()
# Out:
# 1    107
# 2     77
# 3     31
# 6     25
# 5     11
# 4      9
# Name: Lack of classroom atmosphere & background noises , dtype: int64

# %%
sns.countplot(data=data, x='Lack of classroom atmosphere & background noises ')
plt.show()

# %% [markdown]
# The lack of classroom atmosphere, background noises, disturbances from the surroundings, availability of good infrastructural facilities, and the psychological difficulty in adjusting with the sudden shift to online education tends to be the challenges faced by a small group of respondents.

# %%
data.hist(edgecolor='black', linewidth=1)
fig=plt.gcf()
fig.set_size_inches(12,10)

# %% [markdown]
# # **Comparison**

# %%
data.groupby(data['Gender']).size()
# Out:
# Gender
# Female    152
# Male      108
# dtype: int64

# %% [markdown]
# # **Educational Qualification V/S Gender**

# %%
grouped = data.groupby("Gender")["Educational Qualification"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  Graduation         104
#         School              28
#         Post-Graduation     20
# Male    Graduation          60
#         School              36
#         Post-Graduation     12
# Name: Educational Qualification, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Educational Qualification'])

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True, cmap="Pastel1")

# %%
data.groupby(['Educational Qualification','Gender']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %%
contigency= pd.crosstab(data['Gender'], data['Educational Qualification']) 
contigency
c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.022644408582852632
# Reject H0

# %% [markdown]
# # **Gender V/S quality education**

# %%
grouped = data.groupby("Gender")["which is better for quality education"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  Traditional face-to face classes    144
#         Online classes                        8
# Male    Traditional face-to face classes     96
#         Online classes                       12
# Name: which is better for quality education, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['which is better for quality education']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('reject  H0')
else:
    print('Accept H0')
# Out:
# 0.13163528912020248
# Accept H0

# %%
data.groupby(['which is better for quality education','Gender']).size().unstack().plot(kind='bar',figsize=(8,5))
plt.show()

# %% [markdown]
# From the analysis, it is found that there is no significant relationship between gender of the respondents and their opinion on the mode of education for better quality learning. Irrespective of the gender of the respondents ,majority of the respondents are of the opinion that traditional face-to-face education is better for quality education

# %% [markdown]
# # **Gender V/S recharging an additional financial burden**

# %%
grouped = data.groupby("Gender")["recharging an additional financial burden"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  Yes    96
#         No     56
# Male    Yes    62
#         No     46
# Name: recharging an additional financial burden, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['recharging an additional financial burden']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.41969298674002375
# Accept H0

# %%
contigency
# Out:
# recharging an additional financial burden  No  Yes
# Gender
# Female                                     56   96
# Male                                       46   62

# %%
data.groupby(['Gender','recharging an additional financial burden']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# From the analysis, it is found that there is no significant relationship between gender of the respondents and their opinion in recharging an additional financial burden. Irrespective of the gender of the respondents ,majority of the respondents are of the opinion that recharging is an additional financial burden

# %% [markdown]
# # **Gender V/S financial aid from Govt./any other authority**

# %%
grouped = data.groupby("Gender")["financial aid from Govt./any other authority"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  No     140
#         Yes     12
# Male    No     102
#         Yes      6
# Name: financial aid from Govt./any other authority, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['financial aid from Govt./any other authority']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.6281505703888942
# Accept H0

# %%
data.groupby(['Gender','financial aid from Govt./any other authority']).size().unstack().plot(kind='bar',figsize=(8,5))
plt.show()

# %% [markdown]
# The figure depicts whether there is any association between the gender and their opinion on whether they get any financial aid from Govt./any other authority. From the analysis it is clear that majority of both male and female are of the opinion that they are not getting any sort of financial aid from authorities. So there is no association between gender of the respondents and their opinion.

# %% [markdown]
# ## **Educational Qualification V/S which is better for quality education**

# %%
grouped = data.groupby("Educational Qualification")["which is better for quality education"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 Traditional face-to face classes    152
#                            Online classes                       12
# Post-Graduation            Traditional face-to face classes     31
#                            Online classes                        1
# School                     Traditional face-to face classes     57
#                            Online classes                        7
# Name: which is better for quality education, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['which is better for quality education']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Acctep H0')
# Out:
# 0.3825401664373717
# Acctep H0

# %%
data.groupby(['Educational Qualification','which is better for quality education']).size().unstack().plot(kind='bar',figsize=(8,5))
plt.show()

# %% [markdown]
# The analysis checks whether  there is any association between educational qualification of the respondents and their opinion on the type of education for better quality learning. From the analysis it can be seen that irrespective of the educational qualification of the respondents, all are of the opinion that traditional classes are better of quality education and thus there is no association between educational qualification of the respondents and their opinion.

# %% [markdown]
# # **Gender V/S level of satisfaction on E-learning and online classes**

# %%
grouped = data.groupby("Gender")["level of satisfaction on E-learning and online classes"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  Neutral                59
#         Satisfied              54
#         Dissatisfied           27
#         Highly Dissatisfied     8
#         Highly Satisfied        4
# Male    Neutral                41
#         Satisfied              33
#         Dissatisfied           21
#         Highly Dissatisfied    10
#         Highly Satisfied        3
# Name: level of satisfaction on E-learning and online classes, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['level of satisfaction on E-learning and online classes']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.7290995121641175
# Accept H0

# %%
data.groupby(['Gender','level of satisfaction on E-learning and online classes']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the level of satisfaction on e-learning and online classes based on the gender of the respondents. The analysis shows that irrespective of the gender, majority of the respondents are neutral in their opinion. Relatively high number of respondents from both the gender are satisfied with the classes and then stands the dissatisfaction level of the respondents. Only a few respondents are having extreme satisfaction or dissatisfaction regarding the conduct of online classes. It is clear that there is no association between the satisfaction level of respondents with respect to their age.

# %% [markdown]
# # **Educational Qualification V/S level of satisfaction on E-learning and online classes**
#
#
# ---
#
# > Association

# %%
grouped = data.groupby("Educational Qualification")["level of satisfaction on E-learning and online classes"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 Neutral                63
#                            Satisfied              58
#                            Dissatisfied           29
#                            Highly Dissatisfied    10
#                            Highly Satisfied        4
# Post-Graduation            Satisfied              13
#                            Neutral                11
#                            Dissatisfied            4
#                            Highly Satisfied        2
#                            Highly Dissatisfied     2
# School                     Neutral                26
#                            Satisfied              16
#                            Dissatisfied           15
#                            Highly Dissatisfied     6
#                            Highly Satisfied        1
# Name: level of satisfaction on E-learning and online classes, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['level of satisfaction on E-learning and online classes']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.6060736261207593
# Accept H0

# %%
data.groupby(['Educational Qualification','level of satisfaction on E-learning and online classes']).size().unstack().plot(kind='bar',figsize=(8,5))
plt.show()

# %% [markdown]
# The figure shows the opinion of the respondents on their level of satisfaction on e-learning and online classes with regard to their educational qualification. Analysis shows that there is significant difference between the educational qualification and their opinion. It can be seen that unlike others, students pursuing post graduation are very much satisfied with the online classes. Students pursuing their schooling and graduation are more neutral in their opinion and they are dissatisfied when compared to postgraduate students. Thus it is clear that there is association between level of education of the respondents and their satisfaction level on e-learning and online classes.

# %% [markdown]
# # **Educational Qualification V/S financial aid from Govt./any other authority**

# %%
 grouped = data.groupby("Educational Qualification")["financial aid from Govt./any other authority"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 No     152
#                            Yes     12
# Post-Graduation            No      29
#                            Yes      3
# School                     No      61
#                            Yes      3
# Name: financial aid from Govt./any other authority, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['financial aid from Govt./any other authority']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.6588739152975923
# Accept H0

# %%
data.groupby(['Educational Qualification','financial aid from Govt./any other authority']).size().unstack().plot(kind='bar',figsize=(10,8))
plt.show()

# %% [markdown]
# The figure shows the relationship between educational qualification of the respondents and their opinion on whether they get any financial aid from government or any other authority. From the analysis it is found that irrespective of the level of education majority the respondents opinioned that they are not getting any sort of financial aid. Thus there is no association between educational qualification and their opinion.

# %% [markdown]
# From the analysis, it is found that there is no significant relationship between Educational Qualification of the respondents and their opinion in  getting any sort of financial aid from Govt./ any other authority for attending online classes. Irrespective of the Educational Qualification of the respondents ,majority of the respondents are of the opinion that they are not getting any sort of financial aid from Govt./ any other authority for attending online classes

# %% [markdown]
# # **Educational Qualification V/S Mode/Medium of device used for attending online classes**

# %%
grouped = data.groupby("Educational Qualification")["Mode/Medium of device used for attending online classes "]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 Smart Phones                      127
#                            Laptops                            30
#                            TV                                  3
#                            Tab                                 2
#                            Desktop                             1
#                            Face to face traditional class      1
# Post-Graduation            Smart Phones                       19
#                            Laptops                            13
# School                     Smart Phones                       53
#                            Laptops                             4
#                            Tab                                 3
#                            TV                                  2
#                            Desktop                             2
# Name: Mode/Medium of device used for attending online classes , dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['Mode/Medium of device used for attending online classes ']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.008293586774049956
# Reject H0

# %%
data.groupby(['Educational Qualification','Mode/Medium of device used for attending online classes ']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The analysis shows the mode/medium of device used by the respondents for attending online classes on the basis of their educational qualification. Majority of the respondents from all the category uses smartphones for the purpose and next stands laptops. All other modes are used by only a small number of respondents from each category. It is clear that there is no association between the two factors.

# %% [markdown]
# # **Familys Annual Income v/s recharging an additional financial burden**
#
#
# ---
#
# > Association

# %%
grouped = data.groupby("Familys Annual Income")["recharging an additional financial burden"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Familys Annual Income
# 1,00,000 - 2,00,000    No     11
#                        Yes    11
# 25,000 - 50,000        Yes    54
#                        No     21
# 50,000 - 1,00,000      Yes    37
#                        No     30
# Above 2,00,000         No     21
#                        Yes    20
# Below 25,000           Yes    36
#                        No     19
# Name: recharging an additional financial burden, dtype: int64

# %%
contigency= pd.crosstab(data['Familys Annual Income'], data['recharging an additional financial burden']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
p=0.05
# Print the p-value
print(p)
alpha = 0.0523
if p <= alpha:
    print('reject H0')
else:
    print('accept H0')
# Out:
# 0.05
# reject H0

# %%
data.groupby(['Familys Annual Income','recharging an additional financial burden']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The analysis shows that there is association between a family's annual income and their opinion on whether data recharging an additional burden for them. Low income group families, that is , families with an annual income between rs 100000 Opinioned that that are recharging is an additional financial burden for them and high income group that is families with an annual income above rs 100000 do not experience data recharging as an additional financial burden. It can be seen that there is significant difference in opinion among respondents of different income groups with regard to data recharging.

# %% [markdown]
# # **Gender V/S Network/Internet Connection issues**

# %%
grouped = data.groupby("Gender")["Network/Internet Connection issues"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  1    82
#         2    32
#         3    20
#         4    10
#         6     7
#         5     1
# Male    1    47
#         2    28
#         3    14
#         6    13
#         5     3
#         4     3
# Name: Network/Internet Connection issues, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Network/Internet Connection issues']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.06876848384972582
# Accept H0

# %%
data.groupby(['Gender','Network/Internet Connection issues']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the gender wise distribution of the opinion on network/connection issues as a challenge faced by the respondents during online classes. It is clear from the analysis that there is no significant difference between the gender of the respondents and their opinion. Therefore there is no association between the two factors.

# %% [markdown]
# # **Gender V/S Lack of familiarity to the use of technology**
# ---

# %%
grouped = data.groupby("Gender")["Lack of familiarity to the use of technology"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  2    66
#         1    42
#         3    20
#         6    16
#         5     5
#         4     3
# Male    1    45
#         2    31
#         6    14
#         3    10
#         4     5
#         5     3
# Name: Lack of familiarity to the use of technology, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Lack of familiarity to the use of technology']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.07409931961336767
# Accept H0

# %%
data.groupby(['Gender','Lack of familiarity to the use of technology']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The analysis shows the gender wise opinion of the respondents about the lack of familiarity to the use of technology. By observing the data it was found that there was differences in opinion regarding lack of familiarity to the use of technology from different gender groups. But from the analysis it is clear that the differences in opinion is not significant. thus there is no association between two variables.

# %% [markdown]
# # **Gender V/S Lack of good infrastructural facilities**

# %%
grouped = data.groupby("Gender")["Lack of good infrastructural facilities"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  1    61
#         2    43
#         3    18
#         6    12
#         4    10
#         5     8
# Male    1    50
#         2    25
#         3    15
#         6     7
#         5     7
#         4     4
# Name: Lack of good infrastructural facilities, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Lack of good infrastructural facilities']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.7441370232295301
# Accept H0

# %%
data.groupby(['Gender','Lack of good infrastructural facilities']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the gender wise opinion on lack of good infrastructural facilities. From the analysis it is clear that there is not much difference between the opinion of the respondents with respect to their gender. Thus there is no association between the two factors.

# %% [markdown]
# # **Gender V/S Mental/Psychological difficulty with sudden shifting**

# %%
grouped = data.groupby("Gender")["Mental/Psychological difficulty with sudden shifting"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  1    59
#         2    48
#         3    19
#         4    12
#         6    11
#         5     3
# Male    1    35
#         2    34
#         3    17
#         4    10
#         6     8
#         5     4
# Name: Mental/Psychological difficulty with sudden shifting, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Mental/Psychological difficulty with sudden shifting']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.8436342670840329
# Accept H0

# %%
data.groupby(['Gender','Mental/Psychological difficulty with sudden shifting']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# From the figure it is clear that irrespective of the gender of the respondents, both the categories are of the same opinion regarding their mental/psychological difficulty while having a sudden shift to online learning. Thus there is no association between the two factors.

# %% [markdown]
# # **Gender V/S Lack of face-to-face interaction with teachers and friends**

# %%
grouped = data.groupby("Gender")["Lack of face-to-face interaction with teachers and friends"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  1    66
#         2    42
#         3    21
#         6    12
#         5     9
#         4     2
# Male    1    50
#         2    26
#         3    17
#         6     8
#         4     4
#         5     3
# Name: Lack of face-to-face interaction with teachers and friends, dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Lack of face-to-face interaction with teachers and friends']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.6213005810974277
# Accept H0

# %%
data.groupby(['Gender','Lack of face-to-face interaction with teachers and friends']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the gender wise opinion on whether lack of face-to-face interaction with teachers and friends is a major challenge during e-learning. From the analysis it is found that there is no significant difference between the opinion of the respondents with regard to their gender.

# %% [markdown]
# # **Gender V/S Lack of classroom atmosphere & background noises**

# %%
grouped = data.groupby("Gender")["Lack of classroom atmosphere & background noises "]
grouped.apply(lambda x:x.value_counts())
# Out:
# Gender
# Female  1    56
#         2    51
#         3    17
#         6    14
#         5     8
#         4     6
# Male    1    51
#         2    26
#         3    14
#         6    11
#         5     3
#         4     3
# Name: Lack of classroom atmosphere & background noises , dtype: int64

# %%
contigency= pd.crosstab(data['Gender'], data['Lack of classroom atmosphere & background noises ']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.41958273015973213
# Accept H0

# %%
data.groupby(['Gender','Lack of classroom atmosphere & background noises ']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the gender wise opinion of the  respondents on whether lack of classroom atmosphere and background noises while attending the online classes is a major challenge for them. The analysis shows that there is no difference in opinion with respect to the gender of the respondents.

# %% [markdown]
# # **Educational Qualification V/S Lack of familiarity to the use of technology**

# %%
grouped = data.groupby("Educational Qualification")["Lack of familiarity to the use of technology"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 2    62
#                            1    55
#                            3    19
#                            6    18
#                            4     6
#                            5     4
# Post-Graduation            1    12
#                            2     9
#                            6     5
#                            3     3
#                            5     2
#                            4     1
# School                     2    26
#                            1    20
#                            3     8
#                            6     7
#                            5     2
#                            4     1
# Name: Lack of familiarity to the use of technology, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['Lack of familiarity to the use of technology']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept
     H0')
# Out:
# 0.9557413572050586
# Accept H0

# %%
data.groupby(['Educational Qualification','Lack of familiarity to the use of technology']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the educational qualification wise classification of the respondents' opinion on whether they are facing the challenge of lack of familiarity to the use of technology for attending the online classes. From the analysis it is clear that there is  some sort ofdifference between the opinions of various categories of respondents. Most of the respondents pursuing postgraduation gave 1st ranking to lack of familiarity to the use of technology while those pursuing graduation and schooling ranked this challenge as 2nd. It can be inferred that there is no significant differences in opinion with respect to educational qualification.

# %% [markdown]
# # **Educational Qualification V/S Lack of good infrastructural facilities**

# %%
grouped = data.groupby("Educational Qualification")["Lack of good infrastructural facilities"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 1    71
#                            2    46
#                            3    20
#                            6    10
#                            5    10
#                            4     7
# Post-Graduation            1    14
#                            2     6
#                            3     5
#                            6     3
#                            5     2
#                            4     2
# School                     1    26
#                            2    16
#                            3     8
#                            6     6
#                            4     5
#                            5     3
# Name: Lack of good infrastructural facilities, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['Lack of good infrastructural facilities']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.9686563818689083
# Accept H0

# %%
data.groupby(['Educational Qualification','Lack of good infrastructural facilities']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure represents the respondents' educational qualification and their respective opinion on whether they face lack of good infrastructural facilities as a challenge while attending the online classes. From the analysis it is clear that there is no significant difference between the opinion of the respondents with respect to their educational qualifications.

# %% [markdown]
# # **Educational Qualification V/S Mental/Psychological difficulty with sudden shifting**

# %%
grouped = data.groupby("Educational Qualification")["Mental/Psychological difficulty with sudden shifting"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 2    56
#                            1    50
#                            3    26
#                            6    13
#                            4    13
#                            5     6
# Post-Graduation            1    15
#                            2     8
#                            3     5
#                            6     2
#                            5     1
#                            4     1
# School                     1    29
#                            2    18
#                            4     8
#                            3     5
#                            6     4
# Name: Mental/Psychological difficulty with sudden shifting, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['Mental/Psychological difficulty with sudden shifting']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.2765419973711824
# Accept H0

# %%
data.groupby(['Educational Qualification','Mental/Psychological difficulty with sudden shifting']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure represents the respondents' educational qualification and their opinion on whether they posses a mental/psychological difficulty with the sudden shift to online classes. The analysis shows that the p value is greater than 0.05 it makes clear that there is no assoiciation between the educational qualification of the respondents and their opinion.

# %% [markdown]
# # **Educational Qualification V/S Lack of face-to-face interaction with teachers and friends**

# %%
grouped = data.groupby("Educational Qualification")["Lack of face-to-face interaction with teachers and friends"]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 1    67
#                            2    46
#                            3    31
#                            6    12
#                            5     4
#                            4     4
# Post-Graduation            1    14
#                            2    10
#                            3     3
#                            6     2
#                            5     2
#                            4     1
# School                     1    35
#                            2    12
#                            6     6
#                            5     6
#                            3     4
#                            4     1
# Name: Lack of face-to-face interaction with teachers and friends, dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], data['Lack of face-to-face interaction with teachers and friends']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.12446220400610103
# Accept H0

# %%
data.groupby(['Educational Qualification','Lack of face-to-face interaction with teachers and friends']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the educational qualification of the respondents and their opinion on whether lack of face-to-face interaction with teachers and friends stands as a challenge during the online classes. From the analysis it is found that there is no difference in opinion with respect to the educational qualification of the respondents.

# %% [markdown]
# # **Educational Qualification V/S Lack of classroom atmosphere & background noises**

# %%
grouped = data.groupby("Educational Qualification")["Lack of classroom atmosphere & background noises "]
grouped.apply(lambda x:x.value_counts())
# Out:
# Educational Qualification
# Graduation                 1    65
#                            2    54
#                            3    25
#                            6    10
#                            5     6
#                            4     4
# Post-Graduation            1    13
#                            2    11
#                            6     4
#                            4     2
#                            5     1
#                            3     1
# School                     1    29
#                            2    12
#                            6    11
#                            3     5
#                            5     4
#                            4     3
# Name: Lack of classroom atmosphere & background noises , dtype: int64

# %%
contigency= pd.crosstab(data['Educational Qualification'], 
          data['Lack of classroom atmosphere & background noises ']) 

c, p, dof, expected = scipy.stats.chi2_contingency(contigency) 
# Print the p-value
print(p)
alpha = 0.05
if p <= alpha:
    print('Reject H0')
else:
    print('Accept H0')
# Out:
# 0.07890923201197028
# Accept H0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
data.groupby(['Educational Qualification','Lack of classroom atmosphere & background noises ']).size().unstack().plot(kind='bar',figsize=(10,5))
plt.show()

# %% [markdown]
# The figure shows the educational qualification of the respondents and their opinion on whether lack of classroom atmosphere and background noises while attending online classes stands as a major challenge for them. The analysis shows that there is no significant difference between the opinion of the respondents with respect to their educational qualifications.

# %% [markdown]
# # **Thank you**
